# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())

    if n % 2 != 0:
        print("Weird")
    elif n >= 2 and n <= 5:
        print("Not Weird")
    elif n >= 6 and n <= 20:
        print("Weird")
    else:
        print("Not Weird")
# Out:
#  45
# Weird

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
#  3
#  4
# 7
# -1
# 12

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
#  4
#  5
# 0
# 0.8

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i*i)
# Out:
#  4
# 0
# 1
# 4
# 9

# %%
def is_leap(year):
    leap = False
    
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        leap = True
    
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  2016
# True

# %%
if __name__ == '__main__':
    n = int(input())
    print(*(range(1,n+1)),sep="")
# Out:
#  5
# 12345
